# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from pybaseball import playerid_reverse_lookup
from pybaseball import statcast
from pybaseball import playerid_lookup
import openpyxl
import pickle
from pathlib import Path
import os
import re
import time
from datetime import datetime, timedelta
from pybaseball import statcast_single_game, schedule_and_record, pitching_stats_range, batting_stats_range, statcast_pitcher

globalYear = 2010
globalMonth = 4

# %%
batting_columns=['team','league','ab','runs','hits','doub','trip','hr','rbi','bb','avg','obp','slg',
                'est_ba_sa','est_woba_sa','sum_woba']
reliever_columns=['team_relief','league_relief','innings','hits','bb',
                      'k','at_bats','doub','trip','hr','era','ba',
                     'slg','obp','est_ba_sa','est_woba_sa','sum_woba']
def team_abreviator(team,league):
    if team=='Atlanta':
        return 'ATL'
    elif team=='Arizona':
        return 'ARI'
    elif team=='Baltimore':
        return 'BAL'
    elif team=='Boston':
        return 'BOS'
    elif team=='Chicago':
        if league=='MLB-AL':
            return 'CWS'
        else:
            return 'CHC'
    elif team=='Cincinnati':
        return 'CIN'
    elif team=='Cleveland':
        return 'CLE'
    elif team=='Colorado':
        return 'COL'
    elif team=='Detroit':
        return 'DET'
    elif team=='Houston':
        return 'HOU'
    elif team=='Kansas City':
        return 'KC'
    elif team=='Los Angeles':
        if league=='MLB-AL':
            return 'LAA'
        else:
            return 'LAD'
    elif team=='Minnesota':
        return 'MIN'
    elif team=='Milwaukee':
        return 'MIL'
    elif team=='Miami':
        return 'MIA'
    elif team=='New York':
        if league=='MLB-AL':
            return 'NYY'
        else:
            return 'NYM'
    elif team=='Oakland':
        return 'OAK'
    elif team=='Pittsburgh':
        return 'PIT'
    elif team=='Philadelphia':
        return 'PHI'
    elif team=='San Diego':
        return 'SD'
    elif team=='San Francisco':
        return 'SF'
    elif team=='Seattle':
        return 'SEA'
    elif team=='St. Louis':
        return 'STL'
    elif team=='Texas':
        return 'TEX'
    elif team=='Tampa Bay':
        return 'TB'
    elif team=='Toronto':
        return 'TOR'
    elif team=='Washington':
        return 'WSH'
    else:
        print('Team not available in every pitch data')
        return 0

#####
def recent_team_batting(data,every_pitch,start,end,team,league):
    data=data[data.iloc[:,4]==team]
    data=data[data.iloc[:,3]==league]
    ab=data.AB.sum()
    hits=data.H.sum()
    bb=data.BB.sum()+data.IBB.sum()+data.HBP.sum()
    doub=data['2B'].sum()
    trip=data['3B'].sum()
    hr=data.HR.sum()
    rbi=data.RBI.sum()
    avg=round(hits/ab,3)
    obp=round((hits+bb)/ab,3)
    slg=round((hits+doub+(trip*2)+(hr*3))/ab,3)
    runs=data.R.sum()
    data2=every_pitch[every_pitch.game_date<=end]
    data2=data2[data2.game_date>=start]
    team_abrev=team_abreviator(team,league)
    data3=data2[data2.home_team==team_abrev]
    data3=data3[data3.inning_topbot=='Bot']
    data4=data2[data2.away_team==team_abrev]
    data4=data4[data4.inning_topbot=='Top']
    data5=pd.concat([data3,data4])
    data5=data5.dropna(subset=['launch_angle', 'launch_speed', 'estimated_ba_using_speedangle'])
    est_ba_sa=data5.estimated_ba_using_speedangle.mean()
    est_woba_sa=data5.estimated_woba_using_speedangle.mean()
    sum_woba=data5.woba_value.sum()
    df=pd.DataFrame([[team,league,ab,runs,hits,doub,trip,hr,rbi,bb,avg,obp,slg,
                     est_ba_sa,est_woba_sa,sum_woba]],columns=batting_columns)
    return df
#####
def recent_bullpen(data,every_pitch,team,league,lookback_start,lookback_end):
    pen=data[data.Tm==team]
    pen=pen[pen.Lev==league]
    pen.IP=((pen.IP-round(pen.IP,0))*(10/3))+(round(pen.IP,0))
    innings=pen.IP.sum()
    hits=pen.H.sum()*9/innings
    bb=(pen.BB.sum()+pen.HBP.sum()+pen.IBB.sum())*9/innings
    k=pen.SO.sum()*9/innings
    at_bats=pen.AB.sum()*9/innings
    doub=pen['2B'].sum()*9/innings
    trip=pen['3B'].sum()*9/innings
    hr=pen.HR.sum()*9/innings
    era=pen.ER.sum()/innings*9
    ba=hits/at_bats
    slg=round((hits+doub+(trip*2)+(hr*3))/at_bats,3)
    obp=round((hits+bb)/(at_bats+bb),3)
    data2=every_pitch[every_pitch.game_date<=lookback_end]
    data2=data2[data2.game_date>=lookback_start]
    team_abrev=team_abreviator(team,league)
    data3=data2[data2.home_team==team_abrev]
    data3=data3[data3.inning_topbot=='Bot']
    data4=data2[data2.away_team==team_abrev]
    data4=data4[data4.inning_topbot=='Top']
    data5=pd.concat([data3,data4])
    data5=data5.dropna(subset=['launch_angle', 'launch_speed', 'estimated_ba_using_speedangle'])
    est_ba_sa=data5.estimated_ba_using_speedangle.mean()
    est_woba_sa=data5.estimated_woba_using_speedangle.mean()
    sum_woba=data5.woba_value.sum()/innings
    df=pd.DataFrame([[team,league,innings,hits,bb,
                      k,at_bats,doub,trip,hr,era,ba,
                     slg,obp,est_ba_sa,est_woba_sa,sum_woba]],columns=reliever_columns)
    return df
#####

# %%
def get_game_data_range_local():
    listOfEveryPitchFilenames = []

    # List of directories to search
    directories = [
        r"D:\BaseballBetsData1",
        r"D:\BaseballBetsData2",
        r"D:\BaseballBetsData3",
        r"D:\BaseballBetsData4",
        r"D:\BaseballBetsData5",
        r"D:\BaseballBetsData6",
        r"D:\BaseballBetsData7"
    ]

    month_str = f"{globalMonth:02d}"  # Pads single digits with a leading zero
    pattern = rf"{globalYear}_every_pitch_{month_str}_\d{{2}}\.pkl$"

    # Iterate through each specified directory
    for directory in directories:
        if os.path.exists(directory):
            for filename in os.listdir(directory):
                if re.search(pattern, filename):
                    listOfEveryPitchFilenames.append(os.path.join(directory, filename))

    print(f"Found {len(listOfEveryPitchFilenames)} files.")
    return listOfEveryPitchFilenames

# %%
def get_all_starters(data,temp_every_game):
    all_starters={}

    '''
    # Extracting dates from filenames
    splits = [filename.split('_') for filename in temp_every_game]

    # Concatenating the parts of the date and formatting it
    formatSplit = ['{}-{}-{}'.format(date[0], date[3], date[4][0:2]) for date in splits]

    dates = pd.to_datetime(formatSplit)
    '''

    # Extracting dates from filenames
    splits = [filename.split('_') for filename in temp_every_game]

    # Concatenating the parts of the date and formatting it
    formatSplit = ['{}-{}-{}'.format(date[0][-4:], date[3], date[4][0:2]) for date in splits]

    # Convert to datetime
    dates = pd.to_datetime(formatSplit)


    for day in dates:
        day_starters=[]
        day_data=data[data.game_date==day]
        today_games=day_data.game_pk.unique()
        for game in today_games:
            game_stats=day_data[day_data.game_pk==game]
            home_counter=0
            away_counter=0
            l=game_stats.pitcher.value_counts().keys()
            for pitcher in l:
                m=game_stats[game_stats.pitcher==pitcher]
                m.reset_index(drop=True, inplace=True)
                if home_counter==0 and m.inning_topbot[0]=='Bot':
                    home_starter_id=pitcher
                    home_counter+=1
                elif away_counter==0 and m.inning_topbot[0]=='Top':
                    away_starter_id=pitcher
                    away_counter=+1
                else:
                    None
            home_holder=all_players[all_players.key_mlbam==home_starter_id]
            home_holder.reset_index(drop=True,inplace=True)
            home_starter_name=str(home_holder.name_first[0])+' '+str(home_holder.name_last[0])
            away_holder=all_players[all_players.key_mlbam==away_starter_id]
            away_holder.reset_index(drop=True,inplace=True)
            away_starter_name=str(away_holder.name_first[0])+' '+str(away_holder.name_last[0])
            day_starters.append(home_starter_name)
            day_starters.append(away_starter_name)
        exit_date=day.strftime('%Y-%m-%d')
        all_starters.update({exit_date:day_starters})
    return all_starters

def get_all_relievers(starters_on_day,data,temp_every_game):
    all_starters=[]
    # Extracting dates from filenames
    splits = [filename.split('_') for filename in temp_every_game]

    # Concatenating the parts of the date and formatting it
    formatSplit = ['{}-{}-{}'.format(date[0][-4:], date[3], date[4][0:2]) for date in splits]

    dates = pd.to_datetime(formatSplit)

    for day in formatSplit:
        for player in starters_on_day[day]:
            all_starters.append(player)
    f=pd.DataFrame(all_starters,columns=['starters'])
    f=f.starters.unique()
    g=pd.DataFrame(f,columns=['starters'])
    h=pd.merge(data,g,how='outer',left_on='Name',right_on='starters',indicator=True)
    relievers=h[h._merge!='both']
    return relievers

def fetch_data_every_game(game):
    game_ids=[]
    all_pitching_stats=[]
    all_batting_stats=[]
    data=pd.DataFrame([])
    fails=pd.DataFrame([])
    data2=pd.DataFrame([])
    home_starter_stats=pd.DataFrame([])
    away_starter_stats=pd.DataFrame([])
    
    home_batting_stats=pd.DataFrame([],columns=batting_columns)
    away_batting_stats=pd.DataFrame([],columns=batting_columns)
    home_reliever_stats=pd.DataFrame([],columns=reliever_columns)
    away_reliever_stats=pd.DataFrame([],columns=reliever_columns)
    
    all_starting_pitchers=[]
    # harrison check
    '''
    today_games_pickle_in=open(game,"rb")
    today_games=pickle.load(today_games_pickle_in)
    '''

    directories = [
        r"D:\BaseballBetsData1",
        r"D:\BaseballBetsData2",
        r"D:\BaseballBetsData3",
        r"D:\BaseballBetsData4",
        r"D:\BaseballBetsData5",
        r"D:\BaseballBetsData6",
        r"D:\BaseballBetsData7"
    ]

    # Iterate through each specified directory
    for directory in directories:
        full_path = os.path.join(directory, game)
        if os.path.exists(full_path):
            with open(full_path, "rb") as today_games_pickle_in:
                 today_games=pickle.load(today_games_pickle_in)
    

    '''
    temp_all_pitching_stats_fn = game[:4] + "_all_pitching_stats_" + game[17:19] + "_" + game[20:22] + ".pkl"
    all_pitching_stats=open(temp_all_pitching_stats_fn,"rb")
    all_pitching_stats=pickle.load(all_pitching_stats)
    '''
    
    # Extracting year, month, and day
    parts = game.split('_')
    year = parts[0].split('\\')[-1]  # Get '2019'
    month = parts[3]  # Get '04'
    day = parts[4][:2]  # Get '01'

    # Creating the new string
    temp_all_pitching_stats_fn = f"{year}_all_pitching_stats_{month}_{day}.pkl"


    #temp_all_pitching_stats_fn = game[0][-4:] + "_all_pitching_stats_" + game[17:19] + "_" + game[20:22] + ".pkl"

    # List of directories to search
    directories = [
        r"D:\BaseballBetsData1",
        r"D:\BaseballBetsData2",
        r"D:\BaseballBetsData3",
        r"D:\BaseballBetsData4",
        r"D:\BaseballBetsData5",
        r"D:\BaseballBetsData6",
        r"D:\BaseballBetsData7"
    ]

    # Iterate through each specified directory
    for directory in directories:
        full_path = os.path.join(directory, temp_all_pitching_stats_fn)
        if os.path.exists(full_path):
            with open(full_path, "rb") as all_pitching_stats:
                all_pitching_stats=pickle.load(all_pitching_stats)


    if len(all_pitching_stats) == 0:
        return data,fails
    all_pitching_stats.Name=all_pitching_stats.Name.str.lower()

    all_reliever_stats=get_all_relievers(starters_on_day,all_pitching_stats, every_game)

    '''
    temp_all_batting_stats_fn = game[:4] + "_all_batting_stats_" + game[17:19] + "_" + game[20:22] + ".pkl"
    all_batting_stats=open(temp_all_batting_stats_fn,"rb")
    all_batting_stats=pickle.load(all_batting_stats)
    '''

    #temp_all_batting_stats_fn = game[:4] + "_all_batting_stats_" + game[17:19] + "_" + game[20:22] + ".pkl"

    # Extracting year, month, and day
    parts = game.split('_')
    year = parts[0].split('\\')[-1]  # Get '2019'
    month = parts[3]  # Get '04'
    day = parts[4][:2]  # Get '01'

    # Creating the new string
    temp_all_batting_stats_fn = year + "_all_batting_stats_" + month + "_" + day + ".pkl"


    # List of directories to search
    directories = [
        r"D:\BaseballBetsData1",
        r"D:\BaseballBetsData2",
        r"D:\BaseballBetsData3",
        r"D:\BaseballBetsData4",
        r"D:\BaseballBetsData5",
        r"D:\BaseballBetsData6",
        r"D:\BaseballBetsData7"
    ]

    # Iterate through each specified directory
    for directory in directories:
        full_path = os.path.join(directory, temp_all_batting_stats_fn)
        if os.path.exists(full_path):
            with open(full_path, "rb") as all_batting_stats:
                all_batting_stats=pickle.load(all_batting_stats)

    game_ids=today_games.game_pk.unique()
    game_ids=game_ids.astype(int)
    # This deals with the occasional occurance of double headers
    double_header_count={'BOS':0,'MIL':0,'PIT':0,'MIA':0,'ATL':0,'PHI':0,
                      'CIN':0,'TOR':0,'ARI':0,'TEX':0,'OAK':0,'SF':0,
                      'LAD':0,'SD':0,'WSN':0,'NYM':0,'COL':0,'KC':0,
                      'CHW':0,'HOU':0,'BAL':0,'DET':0,'MIN':0,'CLE':0,
                      'NYY':0,'CHC':0,'STL':0,'BOS':0,'TB':0,'TB':0,
                      'LAA':0,'SEA':0}

    '''
    listOfEveryGameFilenames = []
    path = "./"
    gameStatsPattern = rf"{game[:4]}_game_stats_{game[17:19]}_{game[20:22]}_\d+\.pkl$"

    for filename in os.listdir(path):
        if re.search(gameStatsPattern, filename):
            listOfEveryGameFilenames.append(filename)
    print(len(listOfEveryGameFilenames))

    '''

    listOfEveryGameFilenames = []

    # List of directories to search
    directories = [
        r"D:\BaseballBetsData1",
        r"D:\BaseballBetsData2",
        r"D:\BaseballBetsData3",
        r"D:\BaseballBetsData4",
        r"D:\BaseballBetsData5",
        r"D:\BaseballBetsData6",
        r"D:\BaseballBetsData7"
    ]

    # Construct the regex pattern based on the game string
    #gameStatsPattern = rf"{game[:4]}_game_stats_{game[17:19]}_{game[20:22]}_\d+\.pkl$"

        # Extracting year, month, and day
    parts = game.split('_')
    year = parts[0].split('\\')[-1]  # Get '2019'
    month = parts[3]  # Get '04'
    day = parts[4][:2]  # Get '01'

    # Creating the new string
    gameStatsPattern = rf"{year}_game_stats_{month}_{day}_\d+\.pkl$"


    # Iterate through each specified directory
    for directory in directories:
        if os.path.exists(directory):
            for filename in os.listdir(directory):
                #invalid group
                if re.search(gameStatsPattern, filename):
                    listOfEveryGameFilenames.append(os.path.join(directory, filename))




    for gameStatFn in listOfEveryGameFilenames:
        '''
        game_stats=open(gameStatFn,"rb")
        game_stats=pickle.load(game_stats)
        '''

        directories = [
            r"D:\BaseballBetsData1",
            r"D:\BaseballBetsData2",
            r"D:\BaseballBetsData3",
            r"D:\BaseballBetsData4",
            r"D:\BaseballBetsData5",
            r"D:\BaseballBetsData6",
            r"D:\BaseballBetsData7"
        ]

        # Iterate through each specified directory
        for directory in directories:
            full_path = os.path.join(directory, gameStatFn)
            if os.path.exists(full_path):
                with open(full_path, "rb") as game_stats:
                    game_stats=pickle.load(game_stats)

        home,away=game_stats.home_team[0],game_stats.away_team[0]
        home_counter=0
        away_counter=0
        l=game_stats.pitcher.value_counts().keys()
        #determine 'starter' by who threw the most pitches. Normally this would simply be the
        #pitchers who were in the first inning but with the rise of 'bullpenning' this is a work-around
        for pitcher in l:
            m=game_stats[game_stats.pitcher==pitcher]
            m.reset_index(drop=True, inplace=True)
            if home_counter==0 and m.inning_topbot[0]=='Top':
                home_starter_id=pitcher
                home_counter+=1
            elif away_counter==0 and m.inning_topbot[0]=='Bot':
                away_starter_id=pitcher
                away_counter=+1
            else:
                None
        home_holder=all_players[all_players.key_mlbam==home_starter_id]
        home_holder.reset_index(drop=True,inplace=True)
        home_starter_name=str(home_holder.name_first[0])+' '+str(home_holder.name_last[0])
        away_holder=all_players[all_players.key_mlbam==away_starter_id]
        away_holder.reset_index(drop=True,inplace=True)
        away_starter_name=str(away_holder.name_first[0])+' '+str(away_holder.name_last[0])
        # This set of if statements handles cases where a starting pitcher does not have sufficient recent
        # data to be useful in the model. Such as not having pitched in a while or the rare case where there
        # are two pitchers with the same name.
        if len(all_pitching_stats[all_pitching_stats.Name.str.contains(home_holder.name_last[0],regex=False)])==0:
            print('game#: ',game, 'Home: ',home,' Away: ',away,'home pitcher with insuffucicient history')
            fails = pd.concat([fails, pd.DataFrame({'game#':game, 'Home':home,'Away':away,
                                             'Reason':'home pitcher with insuffucicient history'},
                                            index=[0])], ignore_index=True)
            '''
                        fails=fails.append(pd.DataFrame({'game#':game, 'Home':home,'Away':away,
                                             'Reason':'home pitcher with insuffucicient history'},
                                            index=[0]),ignore_index=True)
            '''
            continue
        elif len(all_pitching_stats[all_pitching_stats.Name.str.contains(home_holder.name_last[0],regex=False)])==1:
            home_starter_stats=pd.concat([home_starter_stats, pd.DataFrame(all_pitching_stats[all_pitching_stats.Name.str.contains(home_holder.name_last[0],regex=False)])])
            #home_starter_stats=home_starter_stats.append(pd.DataFrame(all_pitching_stats[all_pitching_stats.Name.str.contains(home_holder.name_last[0],regex=False)]))
        elif len(all_pitching_stats[all_pitching_stats.Name==home_starter_name])==1:
            #home_starter_stats=home_starter_stats.append(pd.DataFrame(all_pitching_stats[all_pitching_stats.Name==home_starter_name]))
            home_starter_stats = pd.concat([home_starter_stats, pd.DataFrame(all_pitching_stats[all_pitching_stats.Name==home_starter_name])])
        else:
            print('game#: ',game,' Home: ',home,' Away: ',away,'home pitcher with duplicate name?')
            fails = pd.concat([fails, pd.DataFrame({'game#':game,'Home':home,'Away':away,
                                             'Reason':'home pitcher with duplicate name?'},
                                            index=[0])], ignore_index=True)
            '''
                        fails=fails.append(pd.DataFrame({'game#':game,'Home':home,'Away':away,
                                             'Reason':'home pitcher with duplicate name?'},
                                            index=[0]),ignore_index=True)
            '''
            None
        if len(all_pitching_stats[all_pitching_stats.Name.str.contains(away_holder.name_last[0],regex=False)])==0:
            print('game#: ',game,' Home: ',home,' Away: ',away,'away pitcher with insuffucicient history')
            fails = pd.concat([fails, pd.DataFrame({'game#':game,'Home':home,'Away':away,
                                             'Reason':'away pitcher with insuffucicient history'},
                                            index=[0])], ignore_index=True)
            '''
                        fails=fails.append(pd.DataFrame({'game#':game,'Home':home,'Away':away,
                                             'Reason':'away pitcher with insuffucicient history'},
                                            index=[0]),ignore_index=True)
            '''
            continue
        elif len(all_pitching_stats[all_pitching_stats.Name.str.contains(away_holder.name_last[0],regex=False)])==1:
            #away_starter_stats=away_starter_stats.append(pd.DataFrame(all_pitching_stats[all_pitching_stats.Name.str.contains(away_holder.name_last[0],regex=False)]))
            away_starter_stats = pd.concat([away_starter_stats, pd.DataFrame(all_pitching_stats[all_pitching_stats.Name.str.contains(away_holder.name_last[0],regex=False)])])
        elif len(all_pitching_stats[all_pitching_stats.Name==away_starter_name])==1:
            #away_starter_stats=away_starter_stats.append(pd.DataFrame(all_pitching_stats[all_pitching_stats.Name==away_starter_name]))
            away_starter_stats = pd.concat([away_starter_stats, pd.DataFrame(all_pitching_stats[all_pitching_stats.Name==away_starter_name])])
        else:
            print('game#: ',game,' Home: ',home,' Away: ',away,'away pitcher with duplicate name?')
            fails = pd.concat([fails, pd.DataFrame({'game#':game,'Home':home,'Away':away,
                                             'Reason':'away pitcher with duplicate name?'},
                                            index=[0])], ignore_index=True)
            '''
                        fails=fails.append(pd.DataFrame({'game#':game,'Home':home,'Away':away,
                                             'Reason':'away pitcher with duplicate name?'},
                                            index=[0]),ignore_index=True)
            '''
            None
        if away_starter_stats.empty or home_starter_stats.empty:
            continue
        # In different databases, there are a couple teams with different abreviations: this handles that.
        if home=='CWS':
            home='CHW'
        else:
            None
        if away=='CWS':
            away='CHW'
        else:
            None
        if home=='AZ':
            home='ARI'
        else:
            None
        if away=='AZ':
            away='ARI'
        else:
            None
        if home=='WSH':
            home='WSN'
        else:
            None
        if away=='WSH':
            away='WSN'
        else:
            None
        # This section is a workaround resulting because one database does not account for
        # extra inning games and leaves such games as a tie. To get around this I had to call
        # a different database and determine the winner by looking at the change in the team's
        # record after the game.
        '''
        home_schedule_record_fn = game[:4] + "_schedule_record_" + home + ".pkl"
        home_schedule_record=open(home_schedule_record_fn,"rb")
        home_schedule_record=pickle.load(home_schedule_record)

        '''

        # Extracting year, month, and day
        parts = game.split('_')
        year = parts[0].split('\\')[-1]  # Get '2019'

        home_schedule_record_fn = year + "_schedule_record_" + home + ".pkl"

        home_schedule_record = None
        away_schedule_record = None

        # List of directories to search
        directories = [
            r"D:\BaseballBetsData1",
            r"D:\BaseballBetsData2",
            r"D:\BaseballBetsData3",
            r"D:\BaseballBetsData4",
            r"D:\BaseballBetsData5",
            r"D:\BaseballBetsData6",
            r"D:\BaseballBetsData7"
        ]

        # Iterate through each specified directory
        for directory in directories:
            full_path = os.path.join(directory, home_schedule_record_fn)
            if os.path.exists(full_path):
                with open(full_path, "rb") as home_schedule_record:
                    home_schedule_record=pickle.load(home_schedule_record)
                    home_schedule_record.set_index('Date',inplace=True)
                break

        '''
        away_schedule_record_fn = game[:4] + "_schedule_record_" + away + ".pkl"
        away_schedule_record=open(away_schedule_record_fn,"rb")
        away_schedule_record=pickle.load(away_schedule_record)
        '''

        parts = game.split('_')
        year = parts[0].split('\\')[-1]  # Get '2019'

        away_schedule_record_fn = year + "_schedule_record_" + away + ".pkl"

        # List of directories to search
        directories = [
            r"D:\BaseballBetsData1",
            r"D:\BaseballBetsData2",
            r"D:\BaseballBetsData3",
            r"D:\BaseballBetsData4",
            r"D:\BaseballBetsData5",
            r"D:\BaseballBetsData6",
            r"D:\BaseballBetsData7"
        ]

        # Iterate through each specified directory
        for directory in directories:
            full_path = os.path.join(directory, away_schedule_record_fn)
            if os.path.exists(full_path):
                with open(full_path, "rb") as away_schedule_record:
                    away_schedule_record=pickle.load(away_schedule_record)
                    away_schedule_record.set_index('Date',inplace=True)
                break

        if away_schedule_record is None or home_schedule_record is None:
            continue

        # Extract year, month, and day from the filename using regular expressions
        match = re.search(r'(\d{4})_every_pitch_(\d{2})_(\d{2})\.pkl', game)
        year = match.group(1)
        month = match.group(2)
        day = match.group(3)

        # Create a datetime object
        date_obj = datetime(int(year), int(month), int(day))

        # Format the date as "YYYY-MM-DD"
        date_string = date_obj.strftime("%Y-%m-%d")

        # Convert the date string to a datetime object
        date = datetime.strptime(date_string, "%Y-%m-%d")
        # Calculate the date 30 days prior
        prior_date = date - timedelta(days=30)
        # Format the prior_date as YYYY-MM-DD
        prior_date_formatted = prior_date.strftime("%Y-%m-%d")
        lookback_end_date = prior_date - timedelta(days=1)
        lookback_end_date_formatted = lookback_end_date.strftime("%Y-%m-%d")


        y,y2,y3=pd.to_datetime(date),pd.to_datetime(lookback_end_date_formatted),pd.to_datetime(prior_date_formatted)
        z,z2,z3=y.day,y2.day,y3.day
        date_string,date_string2,date_string3=str(y.strftime('%A, %b '))+str(z),str(y2.strftime('%A, %b '))+str(z2),str(y3.strftime('%A, %b '))+str(z3)
        date_string4=str(date_string)+str(' (1)')
        date_string5=str(date_string)+str(' (2)')

        if any(item==date_string for item in home_schedule_record.index):
            home_score=home_schedule_record.loc[date_string].R
            away_score=home_schedule_record.loc[date_string].RA
        else:
            if sum([item==date_string for item in home_schedule_record.index])==0 and double_header_count[home]==0:
                home_score=home_schedule_record.loc[date_string4].R
                away_score=home_schedule_record.loc[date_string4].RA
                double_header_count[home]=1
            else:
                home_score=home_schedule_record.loc[date_string5].R
                away_score=home_schedule_record.loc[date_string5].RA
        # determine winner
        if home_score>away_score:
            home_win=1
        elif home_score<away_score:
            home_win=0
        else:
            home_win=-99
        if any(item==date_string2 for item in home_schedule_record.index):
            home_record=home_schedule_record.loc[date_string2]['W-L']
        else:
            for i in range(1,10):
                y4=y2-pd.to_timedelta(i,unit='D')
                y4z=y4.day
                y4zdate=str(y4.strftime('%A, %b '))+str(y4z)
                if any(item==y4zdate for item in away_schedule_record.index):
                    home_record=away_schedule_record.loc[y4zdate]['W-L']
                    break
                else:
                    None
        if any(item==date_string3 for item in home_schedule_record.index):
            home_record_lookback=home_schedule_record.loc[date_string3]['W-L']
        else:
            for i in range(1,10):
                y4=y3-pd.to_timedelta(i,unit='D')
                y4z=y4.day
                y4zdate=str(y4.strftime('%A, %b '))+str(y4z)
                if any(item==y4zdate for item in away_schedule_record.index):
                    home_record_lookback=away_schedule_record.loc[y4zdate]['W-L']
                    break
                else:
                    None
        if any(item==date_string2 for item in away_schedule_record.index):
            away_record=away_schedule_record.loc[date_string2]['W-L']
        else:
            for i in range(1,10):
                y4=y2-pd.to_timedelta(i,unit='D')
                y4z=y4.day
                y4zdate=str(y4.strftime('%A, %b '))+str(y4z)
                if any(item==y4zdate for item in away_schedule_record.index):
                    away_record=away_schedule_record.loc[y4zdate]['W-L']
                    break
                else:
                    None
        if any(item==date_string3 for item in away_schedule_record.index):
            away_record_lookback=away_schedule_record.loc[date_string3]['W-L']
        else:
            for i in range(1,10):
                y4=y3-pd.to_timedelta(i,unit='D')
                y4z=y4.day
                y4zdate=str(y4.strftime('%A, %b '))+str(y4z)
                if any(item==y4zdate for item in away_schedule_record.index):
                    away_record_lookback=away_schedule_record.loc[y4zdate]['W-L']
                    break
                else:
                    None
        # This section determines the season win percentage for each team
        try:
            home_record
        except NameError:
            home_record = "0-0"
        try:
            away_record
        except NameError:
            away_record = "0-0"
        try:
            home_current_wins,home_current_losses=int(home_record.split('-')[0]),int(home_record.split('-')[1])
            away_current_wins,away_current_losses=int(away_record.split('-')[0]),int(away_record.split('-')[1])
            home_pct = 0
            away_pct = 0
            try:
                home_pct=home_current_wins/(home_current_wins+home_current_losses)
            except:
                home_pct = 0
            try:
                away_pct=away_current_wins/(away_current_wins+away_current_losses)
            except:
                away_pct = 0
            try:
                home_record_lookback
            except:
                home_record_lookback = "0-0"
            try:
                away_record_lookback
            except:
                away_record_lookback = "0-0"
            # This section determines the recent win percentage for each team
            home_lookback_wins,home_lookback_losses=int(home_record_lookback.split('-')[0]),int(home_record_lookback.split('-')[1])
            away_lookback_wins,away_lookback_losses=int(away_record_lookback.split('-')[0]),int(away_record_lookback.split('-')[1])
            home_recent_wins,home_recent_losses=home_current_wins-home_lookback_wins,home_current_losses-home_lookback_losses
            away_recent_wins,away_recent_losses=away_current_wins-away_lookback_wins,away_current_losses-away_lookback_losses
            try:
                home_streak=home_recent_wins/(home_recent_wins+home_recent_losses)
            except:
                home_streak = 0
            try:
                away_streak=away_recent_wins/(away_recent_wins+away_recent_losses)
            except:
                away_streak = 0
            # This section gathers some advanced statistics about the starting pitchers
            '''
            temp_home_statcast_pitcher_fn = year + "_statcast_pitcher_" + month + "_" + day + "_" + gameStatFn.split('_')[-1].split('.')[0] + "_home.pkl"
            temp_home_statcast_pitcher_pickle_in = open(temp_home_statcast_pitcher_fn,"rb")
            home_starter_adv=pickle.load(temp_home_statcast_pitcher_pickle_in)
            '''

            temp_home_statcast_pitcher_fn = f"{year}_statcast_pitcher_{month}_{day}_{gameStatFn.split('_')[-1].split('.')[0]}_home.pkl"

            # List of directories to search
            directories = [
                r"D:\BaseballBetsData1",
                r"D:\BaseballBetsData2",
                r"D:\BaseballBetsData3",
                r"D:\BaseballBetsData4",
                r"D:\BaseballBetsData5",
                r"D:\BaseballBetsData6",
                r"D:\BaseballBetsData7"
            ]

            # Iterate through each specified directory
            for directory in directories:
                full_path = os.path.join(directory, temp_home_statcast_pitcher_fn)
                if os.path.exists(full_path):
                    with open(full_path, "rb") as temp_home_statcast_pitcher_pickle_in:
                        home_starter_adv=pickle.load(temp_home_statcast_pitcher_pickle_in)

        except Exception as e:
            print("error collecting wins/losses", e)
            continue

        if len(home_starter_adv)==0 or "error" in home_starter_adv:
            print('No home starter advanced stats')
            fails = pd.concat([fails, pd.DataFrame({'game#':game,'Home':home,'Away':away,
                                             'Reason':'No home starter advanced stats'},index=[0])], ignore_index=True)
            '''
                        fails=fails.append(pd.DataFrame({'game#':game,'Home':home,'Away':away,
                                             'Reason':'No home starter advanced stats'},index=[0]),ignore_index=True)
            '''
            continue
        else:
            None
        home_starter_launch=home_starter_adv.launch_speed.mean()
        home_starter_adv = home_starter_adv.dropna(subset=['launch_angle', 'launch_speed', 'estimated_ba_using_speedangle'])
        home_starter_est_ba_sa=home_starter_adv.estimated_ba_using_speedangle.mean()
        home_starter_est_woba_sa=home_starter_adv.estimated_woba_using_speedangle.mean()
        home_starter_sum_woba=home_starter_adv.woba_value.sum()

        '''
        temp_away_statcast_pitcher_fn = year + "_statcast_pitcher_" + month + "_" + day + "_" + gameStatFn.split('_')[-1].split('.')[0] + "_away.pkl"
        temp_away_statcast_pitcher_pickle_in = open(temp_away_statcast_pitcher_fn,"rb")
        away_starter_adv=pickle.load(temp_away_statcast_pitcher_pickle_in)
        '''

        temp_away_statcast_pitcher_fn = f"{year}_statcast_pitcher_{month}_{day}_{gameStatFn.split('_')[-1].split('.')[0]}_away.pkl"

        # List of directories to search
        directories = [
            r"D:\BaseballBetsData1",
            r"D:\BaseballBetsData2",
            r"D:\BaseballBetsData3",
            r"D:\BaseballBetsData4",
            r"D:\BaseballBetsData5",
            r"D:\BaseballBetsData6",
            r"D:\BaseballBetsData7"
        ]

        # Iterate through each specified directory
        for directory in directories:
            full_path = os.path.join(directory, temp_away_statcast_pitcher_fn)
            if os.path.exists(full_path):
                with open(full_path, "rb") as temp_away_statcast_pitcher_pickle_in:
                    away_starter_adv=pickle.load(temp_away_statcast_pitcher_pickle_in)


        if len(away_starter_adv)==0 or "error" in home_starter_adv:
            print('No away starter advanced stats')
            fails = pd.concat([fails, pd.DataFrame({'game#':game,'Home':home,'Away':away,
                                             'Reason':'No away starter advanced stats'},index=[0])], ignore_index=True)
            '''
                        fails=fails.append(pd.DataFrame({'game#':game,'Home':home,'Away':away,
                                             'Reason':'No away starter advanced stats'},index=[0]),ignore_index=True)
            '''
            continue
        else:
            None
        away_starter_launch=away_starter_adv.launch_speed.mean()
        away_starter_adv = away_starter_adv.dropna(subset=['launch_angle', 'launch_speed', 'estimated_ba_using_speedangle'])
        away_starter_est_ba_sa=away_starter_adv.estimated_ba_using_speedangle.mean()
        away_starter_est_woba_sa=away_starter_adv.estimated_woba_using_speedangle.mean()
        away_starter_sum_woba=away_starter_adv.woba_value.sum()
        data = pd.concat([data, pd.DataFrame({'home_win':home_win,'home_score':home_score,
                                       'away_score':away_score,'date':date,'lookback_days':'30',
                                       'home_team':home,'away_team':away,'home_pct':home_pct,'away_pct':away_pct,
                                       'home_streak':home_streak,'away_streak':away_streak,
                                       'home_starter_name':home_starter_name,
                                       'away_starter_name':away_starter_name,'home_starter_id':home_starter_id,
                                       'away_starter_id':away_starter_id,'home_starter_launch':home_starter_launch,
                                       'home_starter_est_ba_sa':home_starter_est_ba_sa,
                                       'home_starter_est_woba_sa':home_starter_est_woba_sa,
                                       'home_starter_sum_woba':home_starter_sum_woba,
                                      'away_starter_launch':away_starter_launch,
                                      'away_starter_est_ba_sa':away_starter_est_ba_sa,
                                       'away_starter_est_woba_sa':away_starter_est_woba_sa,
                                       'away_starter_sum_woba':away_starter_sum_woba},index=[0])], ignore_index=True)
        '''
                data=data.append(pd.DataFrame({'home_win':home_win,'home_score':home_score,
                                       'away_score':away_score,'date':date,'lookback_days':'30',
                                       'home_team':home,'away_team':away,'home_pct':home_pct,'away_pct':away_pct,
                                       'home_streak':home_streak,'away_streak':away_streak,
                                       'home_starter_name':home_starter_name,
                                       'away_starter_name':away_starter_name,'home_starter_id':home_starter_id,
                                       'away_starter_id':away_starter_id,'home_starter_launch':home_starter_launch,
                                       'home_starter_est_ba_sa':home_starter_est_ba_sa,
                                       'home_starter_est_woba_sa':home_starter_est_woba_sa,
                                       'home_starter_sum_woba':home_starter_sum_woba,
                                      'away_starter_launch':away_starter_launch,
                                      'away_starter_est_ba_sa':away_starter_est_ba_sa,
                                       'away_starter_est_woba_sa':away_starter_est_woba_sa,
                                       'away_starter_sum_woba':away_starter_sum_woba},index=[0]),ignore_index=True)

        '''
        all_starting_pitchers.append(home_starter_name)
        all_starting_pitchers.append(away_starter_name)
        home_starter_stats.reset_index(drop=True,inplace=True)
        away_starter_stats.reset_index(drop=True,inplace=True)
        # This section calls the other functions and gathers data about each team
        home_batting=recent_team_batting(all_batting_stats,every_pitch,prior_date_formatted, lookback_end_date_formatted,home_starter_stats.Tm[len(home_starter_stats)-1],home_starter_stats.Lev[len(home_starter_stats)-1])
        #home_batting_stats=home_batting_stats.append((pd.DataFrame(home_batting)))
        home_batting_stats = pd.concat([home_batting_stats, pd.DataFrame(home_batting)])
        away_batting=recent_team_batting(all_batting_stats,every_pitch,prior_date_formatted, lookback_end_date_formatted,away_starter_stats.Tm[len(away_starter_stats)-1],away_starter_stats.Lev[len(away_starter_stats)-1])
        #away_batting_stats=away_batting_stats.append((pd.DataFrame(away_batting)))
        away_batting_stats = pd.concat([away_batting_stats, pd.DataFrame(away_batting)])
        home_relief=recent_bullpen(all_reliever_stats,every_pitch,home_starter_stats.Tm[len(home_starter_stats)-1],
                                   home_starter_stats.Lev[len(home_starter_stats)-1],prior_date_formatted,lookback_end_date_formatted)
        home_reliever_stats = pd.concat([home_reliever_stats, pd.DataFrame(home_relief)])
        #home_reliever_stats=home_reliever_stats.append((pd.DataFrame(home_relief)))
        away_relief=recent_bullpen(all_reliever_stats,every_pitch,away_starter_stats.Tm[len(away_starter_stats)-1],
                                   away_starter_stats.Lev[len(away_starter_stats)-1],prior_date_formatted,lookback_end_date_formatted)
        #away_reliever_stats=away_reliever_stats.append((pd.DataFrame(away_relief)))
        away_reliever_stats = pd.concat([away_reliever_stats, pd.DataFrame(away_relief)])


    if data.empty:
        return data,fails
    data['home_join']=data.home_starter_name.str.replace(' ','')
    data['away_join']=data.away_starter_name.str.replace(' ','')
    home_starter_stats.columns=['hs'+str(col) for col in home_starter_stats.columns]
    away_starter_stats.columns=['as'+str(col) for col in away_starter_stats.columns]
    home_batting_stats.columns=['home_bat_'+str(col) for col in home_batting_stats.columns]
    away_batting_stats.columns=['away_bat_'+str(col) for col in away_batting_stats.columns]
    home_reliever_stats.columns=['homepen_'+str(col) for col in home_reliever_stats.columns]
    away_reliever_stats.columns=['awaypen_'+str(col) for col in away_reliever_stats.columns]
    home_starter_stats['hsjoin']=home_starter_stats.hsName.str.replace(' ','')
    away_starter_stats['asjoin']=away_starter_stats.asName.str.replace(' ','')
    data=data.merge(home_starter_stats,left_on='home_join',right_on='hsjoin')
    data=data.merge(away_starter_stats,left_on='away_join',right_on='asjoin')
    data=data.merge(home_batting_stats,how='left',left_on=['hsTm','hsLev'],right_on=['home_bat_team','home_bat_league'])
    data=data.merge(away_batting_stats,how='left',left_on=['asTm','asLev'],right_on=['away_bat_team','away_bat_league'])
    data=data.merge(home_reliever_stats,how='left',left_on=['hsTm','hsLev'],right_on=['homepen_team_relief','homepen_league_relief'])
    data=data.merge(away_reliever_stats,how='left',left_on=['asTm','asLev'],right_on=['awaypen_team_relief','awaypen_league_relief'])
    data.drop(['hsTm','asTm','away_join','home_join','asName','as#days',
                'asAge','asLev','hsName','hs#days','hsAge','hsLev','hsjoin',
                'asjoin','homepen_team_relief','homepen_league_relief',
               'awaypen_team_relief','awaypen_league_relief'],axis=1,inplace=True)
    data=data.drop_duplicates()
    return data,fails

# %%
def fetch_game_data_wrapper(every_game):
    data=pd.DataFrame([])
    fails=pd.DataFrame([])
    for game in every_game:
        day_data,day_fails=fetch_data_every_game(game)
        data=pd.concat([data,day_data],ignore_index=True)
        fails=pd.concat([fails,day_fails],ignore_index=True)
    return data

# %%
every_game = get_game_data_range_local()

every_pitch = pd.DataFrame([])

for game in every_game:
    '''
    today_games_pickle_in=open(game,"rb")
    today_games=pickle.load(today_games_pickle_in)
    '''

    directories = [
        r"D:\BaseballBetsData1",
        r"D:\BaseballBetsData2",
        r"D:\BaseballBetsData3",
        r"D:\BaseballBetsData4",
        r"D:\BaseballBetsData5",
        r"D:\BaseballBetsData6",
        r"D:\BaseballBetsData7"
    ]

    # Iterate through each specified directory
    for directory in directories:
        full_path = os.path.join(directory, game)
        if os.path.exists(full_path):
            with open(full_path, "rb") as today_games_pickle_in:
                today_games=pickle.load(today_games_pickle_in)

    every_pitch = pd.concat([every_pitch, today_games], ignore_index=True)

all_players=open("wrangle_data_all_players.pkl", "rb")
all_players=pickle.load(all_players)

# use every pitch instead files instead of the hard coded dates
starters_on_day=get_all_starters(every_pitch,every_game)

game_data = fetch_game_data_wrapper(every_game)


# The section below transforms the dates into the form that matches the rest of this notebook
csv_str_file_name = 'mlb-odds-' + str(globalYear) + '.csv'
odds_data=pd.read_csv(csv_str_file_name)
odds_data['month']=round(odds_data.Date/100).astype(int)
odds_data['day']=(odds_data.Date-odds_data.month*100).astype(int)
odds_data['game_day']=0
# This corrects team abreviations from the odds_data file
for i in range(len(odds_data)):
    if odds_data.Team[i]=='SFO':
        odds_data.Team[i]='SF'
    elif odds_data.Team[i]=='WAS':
        odds_data.Team[i]='WSN'
    elif odds_data.Team[i]=='TAM':
        odds_data.Team[i]='TB'
    elif odds_data.Team[i]=='CWS':
        odds_data.Team[i]='CHW'
    elif odds_data.Team[i]=='KAN':
        odds_data.Team[i]='KC'
    elif odds_data.Team[i]=='CUB':
        odds_data.Team[i]='CHC'
    elif odds_data.Team[i]=='SDG':
        odds_data.Team[i]='SD'
    else:
        None
    month=odds_data.month[i]
    day=odds_data.day[i]
    odds_data['game_day'][i]=datetime(globalYear,month,day).strftime('%Y-%m-%d')
# This initiates the necessary variables
game_data['home_money_open']=None
game_data['home_money_close']=None
game_data['home_money_change']=None
game_data['away_money_open']=None
game_data['away_money_close']=None
game_data['away_money_change']=None
game_data['home_prob_open']=None
game_data['home_prob_close']=None
game_data['home_prob_change']=None
game_data['ou_open']=None
game_data['ou_close']=None
# This function uses the money line odds to calculate the betting markets implied
# probablility of the home team winning
def home_pct_chance(home_money,away_money):
    if home_money>0:
        a1=100/(home_money+100)
    else:
        a1=-home_money/(100-home_money)
    if away_money>0:
        a2=100/(away_money+100)
    else:
        a2=-away_money/(100-away_money)
    return(a1/(a1+a2))
# This for loop fills in the relevant betting related columns into the data frame
for i in range(len(game_data)):
    print("in loop " + str(i))
    #try:
    home=[]
    away=[]
    date=game_data.date[i].strftime('%Y-%m-%d')
    home_team=game_data.home_team[i]
    away_team=game_data.away_team[i]
    home=odds_data.loc[(odds_data['game_day'] == date) & (odds_data['Team'] == home_team)]
    away=odds_data.loc[(odds_data['game_day'] == date) & (odds_data['Team'] == away_team)]
    print("home data from odds_data", home)
    print("away data from odds_data", away)
    if odds_data.empty or home.empty or away.empty:
        continue
    home.reset_index(drop=True,inplace=True)
    away.reset_index(drop=True,inplace=True)
    game_data.home_money_close[i]=int(home.Close[0])
    if home.Open[0]=='NL':
        game_data.home_money_open[i]=game_data.home_money_close[i]
        game_data.home_money_change[i]=0
    else:
        game_data.home_money_open[i]=int(home.Open[0])
        game_data.home_money_change[i]=int(home.Close[0])-int(home.Open[0])
    game_data.away_money_close[i]=int(away.Close[0])
    if away.Open[0]=='NL':
        game_data.away_money_open[i]=game_data.away_money_close[i]
        game_data.away_money_change[i]=0
    else:
        game_data.away_money_open[i]=int(away.Open[0])
        game_data.away_money_change[i]=int(away.Close[0])-int(away.Open[0])
    game_data.home_prob_open[i]=home_pct_chance(game_data.home_money_open[i],game_data.away_money_open[i])
    game_data.home_prob_close[i]=home_pct_chance(game_data.home_money_close[i],game_data.away_money_close[i])
    game_data.home_prob_change[i]=game_data.home_prob_close[i]-game_data.home_prob_open[i]
    game_data.ou_open[i]=home.OpenOU[0]
    game_data.ou_close[i]=away.CloseOU[0]
'''

    except Exception as e:
        print("e in game_data loop", e)
        None
        '''
if not game_data.empty:
    game_data=game_data.fillna(0)
    game_data=game_data[game_data.home_streak<1.001]
    game_data=game_data[game_data.away_streak<1.001]
    game_data=game_data[game_data.home_streak>-.001]
    game_data=game_data[game_data.away_streak>-.001]
    df=game_data.copy()
    home_dummies=pd.get_dummies(df.home_team)
    away_dummies=pd.get_dummies(df.away_team)
    home_dummies.columns=['h_'+str(col) for col in home_dummies.columns]
    away_dummies.columns=['a_'+str(col) for col in away_dummies.columns]
    df=df.merge(home_dummies,left_index=True,right_index=True)
    df=df.merge(away_dummies,left_index=True,right_index=True)
    df.drop(['date','lookback_days','home_team','away_team','home_starter_name',
             'away_starter_name','home_starter_id','away_starter_id','home_bat_team','home_bat_league',
            'away_bat_team','away_bat_league'],axis=1,inplace=True)
    # This moves the final moneyline to the last columns to make it easier to examine the real world application later on
    df['home_money_close2']=df.home_money_close
    df['away_money_close2']=df.away_money_close
    df.drop(['home_money_close','away_money_close'],axis=1,inplace=True)
    df['home_money_close']=df.home_money_close2
    df['away_money_close']=df.away_money_close2
    df.drop(['home_money_close2','away_money_close2'],axis=1,inplace=True)
    df.reset_index(drop=True,inplace=True)
    # Load existing data from the pickle file if it exists
    if os.path.exists("cleaned_data.pickle"):
        with open("cleaned_data.pickle", "rb") as pickle_in:
            existing_data = pickle.load(pickle_in)
    else:
        existing_data = pd.DataFrame()

    # Assuming df is the new data you want to append
    existing_data = pd.concat([existing_data, df], ignore_index=True)

    # Save the updated data back to the pickle file
    with open("cleaned_data.pickle", "wb") as pickle_out:
        pickle.dump(existing_data, pickle_out)


    '''
    pickle_out=open("cleaned_data.pickle","wb")
    pickle.dump(df,pickle_out)
    pickle_out.close()
    print("cleaned_data.pickle", df)
    '''
# Out:
# Found 27 files.
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_05.pkl  Home:  MIL  Away:  COL away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_05.pkl  Home:  OAK  Away:  SEA away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_06.pkl Home:  HOU  Away:  SF home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_06.pkl  Home:  BOS  Away:  NYY away pitcher with duplicate name?
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_07.pkl  Home:  CWS  Away:  CLE away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_08.pkl Home:  LAA  Away:  MIN home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_08.pkl  Home:  TEX  Away:  TOR home pitcher with duplicate name?
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_09.pkl  Home:  TB  Away:  NYY away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_09.pkl Home:  AZ  Away:  PIT home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_09.pkl Home:  SF  Away:  ATL home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_10.pkl Home:  CWS  Away:  MIN home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_10.pkl  Home:  TEX  Away:  SEA away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_10.pkl  Home:  MIL  Away:  STL away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_10.pkl Home:  NYM  Away:  WSH home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_11.pkl Home:  MIA  Away:  LAD home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_11.pkl  Home:  TB  Away:  NYY away pitcher with duplicate name?
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_11.pkl Home:  COL  Away:  SD home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_11.pkl  Home:  NYM  Away:  WSH away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_12.pkl Home:  CLE  Away:  TEX home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_12.pkl  Home:  STL  Away:  HOU away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_14.pkl Home:  NYY  Away:  LAA home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_14.pkl  Home:  LAD  Away:  AZ away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_14.pkl Home:  SF  Away:  PIT home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_15.pkl  Home:  TOR  Away:  CWS away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_16.pkl Home:  SEA  Away:  DET home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_16.pkl  Home:  PHI  Away:  MIA away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_16.pkl  Home:  NYY  Away:  TEX away pitcher with duplicate name?
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_16.pkl  Home:  STL  Away:  NYM away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_17.pkl  Home:  ATL  Away:  COL away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_17.pkl Home:  WSH  Away:  MIL home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_17.pkl  Home:  NYY  Away:  TEX home pitcher with duplicate name?
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_17.pkl Home:  STL  Away:  NYM home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_18.pkl Home:  CLE  Away:  CWS home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_18.pkl  Home:  CHC  Away:  HOU away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_19.pkl Home:  LAA  Away:  DET home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_19.pkl Home:  AZ  Away:  STL home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_20.pkl  Home:  OAK  Away:  NYY away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_20.pkl  Home:  SD  Away:  SF away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_21.pkl Home:  SEA  Away:  BAL home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_21.pkl Home:  NYM  Away:  CHC home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_22.pkl Home:  WSH  Away:  COL home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_22.pkl  Home:  BOS  Away:  TEX away pitcher with duplicate name?
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_22.pkl  Home:  HOU  Away:  MIA away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_23.pkl  Home:  LAA  Away:  NYY away pitcher with duplicate name?
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_23.pkl  Home:  SF  Away:  STL away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_24.pkl  Home:  OAK  Away:  CLE away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_24.pkl Home:  LAA  Away:  NYY home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_24.pkl Home:  CWS  Away:  SEA home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_24.pkl Home:  HOU  Away:  PIT home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_25.pkl  Home:  LAA  Away:  NYY away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_25.pkl Home:  AZ  Away:  PHI home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_26.pkl  Home:  KC  Away:  SEA away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_26.pkl Home:  SF  Away:  PHI home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_27.pkl Home:  COL  Away:  AZ home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_27.pkl  Home:  TEX  Away:  CWS home pitcher with duplicate name?
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_27.pkl Home:  MIA  Away:  SD home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_27.pkl  Home:  CHC  Away:  WSH away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_28.pkl Home:  STL  Away:  ATL home pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_29.pkl  Home:  BAL  Away:  NYY away pitcher with duplicate name?
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_30.pkl  Home:  DET  Away:  LAA away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_30.pkl  Home:  CHC  Away:  AZ away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_30.pkl  Home:  NYY  Away:  CWS away pitcher with insuffucicient history
# game#:  D:\BaseballBetsData1\2010_every_pitch_04_30.pkl Home:  CLE  Away:  MIN home pitcher with insuffucicient history
# in loop 0
# home data from odds_data     Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 13   405  ATL  DLOWE-R  -130   -125     8.5     8.5      4    5  2010-04-05
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 12   405  CHC  CZAMBRANO-R   110    105     8.5     8.5      4    5
#
#       game_day
# 12  2010-04-05
# in loop 1
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 19   405  CHW  MBUEHRLE-L  -170   -142     9.0       9      4    5  2010-04-05
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 18   405  CLE  WESTBROOK-R   150    122     9.0       9      4    5
#
#       game_day
# 18  2010-04-05
# in loop 2
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 23   405   KC  ZGREINKE-R  -115   -122     7.0       7      4    5  2010-04-05
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 22   405  DET  VERLANDER-R  -105    102     7.0       7      4    5
#
#       game_day
# 22  2010-04-05
# in loop 3
# home data from odds_data    Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 9   405  PIT  ZDUKE-L   135    106     8.5     8.5      4    5  2010-04-05
# away data from odds_data Empty DataFrame
# Columns: [Date, Team, Pitcher, Open, Close, OpenOU, CloseOU, month, day, game_day]
# Index: []
# in loop 4
# home data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 25   405  LAA  JERWEAVER-R  -135   -128     8.5     8.5      4    5
#
#       game_day
# 25  2010-04-05
# away data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 24   405  MIN  SBAKER-R   115    108     8.5     8.5      4    5  2010-04-05
# in loop 5
# home data from odds_data    Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 3   405  WSN  JLANNAN-L   170    170     7.5     7.5      4    5  2010-04-05
# away data from odds_data    Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 2   405  PHI  RHALLADAY-R  -200   -200     7.5     7.5      4    5  2010-04-05
# in loop 6
# home data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 15   405  ARI  DHAREN-R  -175   -186     8.0       8      4    5  2010-04-05
# away data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 14   405   SD  JGARLAND-R   155    166     8.0       8      4    5  2010-04-05
# in loop 7
# home data from odds_data    Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 7   405  CIN  AHARANG-R   135    123     7.5     7.5      4    5  2010-04-05
# away data from odds_data    Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 6   405  STL  CARPENTER-R  -155   -143     7.5     7.5      4    5  2010-04-05
# in loop 8
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 21   405  TEX  SFELDMAN-R  -135   -150     9.5       9      4    5  2010-04-05
# away data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 20   405  TOR  SMARCUM-R   115    130     9.5       9      4    5  2010-04-05
# in loop 9
# home data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 17   405  HOU  ROSWALT-R   110    127     7.5       7      4    5  2010-04-05
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 16   405   SF  TLINCECUM-R  -130   -147     7.5       7      4    5
#
#       game_day
# 16  2010-04-05
# in loop 10
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 35   406   TB  JSHIELDS-R  -155   -230     8.5       9      4    6  2010-04-06
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 34   406  BAL  KMILLWOOD-R   135    200     8.5       9      4    6
#
#       game_day
# 34  2010-04-06
# in loop 11
# home data from odds_data     Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 31   406  MIL  RWOLF-L  -140   -158     8.5       9      4    6  2010-04-06
# away data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 30   406  COL  GSMITH-L   120    138     8.5       9      4    6  2010-04-06
# in loop 12
# home data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 39   406  LAA  JSAUNDERS-L  -125   -139     9.0      10      4    6
#
#       game_day
# 39  2010-04-06
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 38   406  MIN  NBLACKBUR-R   105    119     9.0      10      4    6
#
#       game_day
# 38  2010-04-06
# in loop 13
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 33   406  ARI  EJACKSON-R  -170   -142     9.0     9.5      4    6  2010-04-06
# away data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 32   406   SD  CYOUNG-R   150    122     9.0     9.5      4    6  2010-04-06
# in loop 14
# home data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 41   406  OAK  DBRADEN-L  -150   -125     8.5     8.5      4    6  2010-04-06
# away data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 40   406  SEA  ISNELL-R   130    105     8.5     8.5      4    6  2010-04-06
# in loop 15
# home data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 61   407   TB  MGARZA-R  -185   -220     9.0       9      4    7  2010-04-07
# away data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 60   407  BAL  JGUTHRIE-R   165    190     9.0       9      4    7  2010-04-07
# in loop 16
# home data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 51   407  ATL  JJURRJENS-R  -160   -143     8.5       8      4    7
#
#       game_day
# 51  2010-04-07
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 50   407  CHC  RDEMPSTER-R   140    123     8.5       8      4    7
#
#       game_day
# 50  2010-04-07
# in loop 17
# home data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 43   407  MIL  DDAVIS-L  -105   -106     9.0       9      4    7  2010-04-07
# away data from odds_data     Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 42   407  COL  ACOOK-R  -105   -114     9.0       9      4    7  2010-04-07
# in loop 18
# home data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 67   407   KC  LHOCHEVAR-R  -102    107     9.0     8.5      4    7
#
#       game_day
# 67  2010-04-07
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 66   407  DET  MSCHERZER-R  -118   -127     9.0     8.5      4    7
#
#       game_day
# 66  2010-04-07
# in loop 19
# home data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 47   407  PIT  ROHLENDOR-R   112    150     8.0       8      4    7
#
#       game_day
# 47  2010-04-07
# away data from odds_data Empty DataFrame
# Columns: [Date, Team, Pitcher, Open, Close, OpenOU, CloseOU, month, day, game_day]
# Index: []
# in loop 20
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 69   407  LAA  ESANTANA-R  -130   -135     9.5     9.5      4    7  2010-04-07
# away data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 68   407  MIN  CPAVANO-R   110    115     9.5     9.5      4    7  2010-04-07
# in loop 21
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 49   407  WSN  JMARQUIS-R   137    165     9.0       9      4    7  2010-04-07
# away data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 48   407  PHI  CHAMELS-L  -157   -185     9.0       9      4    7  2010-04-07
# in loop 22
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 57   407  ARI  IKENNEDY-R  -121   -131     9.5     9.5      4    7  2010-04-07
# away data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 56   407   SD  KCORREIA-R   101    111     9.5     9.5      4    7  2010-04-07
# in loop 23
# home data from odds_data     Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 71   407  OAK  DUCHSHERER-R  -105   -122     8.0     7.5      4    7
#
#       game_day
# 71  2010-04-07
# away data from odds_data     Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 70   407  SEA  RWLND-SMTH-L  -105    102     8.0     7.5      4    7
#
#       game_day
# 70  2010-04-07
# in loop 24
# home data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 53   407  CIN  JCUETO-R   105    124     8.0       8      4    7  2010-04-07
# away data from odds_data     Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 52   407  STL  WAINWRIGHT-R  -125   -144     8.0       8      4    7
#
#       game_day
# 52  2010-04-07
# in loop 25
# home data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 63   407  TEX  RHARDEN-R  -158   -176     9.0       9      4    7  2010-04-07
# away data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 62   407  TOR  BTALLET-L   138    156     9.0       9      4    7  2010-04-07
# in loop 26
# home data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 45   407  HOU  BMYERS-R   110    114     7.5     7.5      4    7  2010-04-07
# away data from odds_data     Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 44   407   SF  MCAIN-R  -130   -134     7.5     7.5      4    7  2010-04-07
# in loop 27
# home data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 59   407  BOS  JLACKEY-R  -135   -138    10.0      10      4    7  2010-04-07
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 58   407  NYY  APETTITTE-L   115    118    10.0      10      4    7
#
#       game_day
# 58  2010-04-07
# in loop 28
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 89   408   TB  JNIEMANN-R  -189   -160     9.5     9.5      4    8  2010-04-08
# away data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 88   408  BAL  BMATUSZ-L   169    140     9.5     9.5      4    8  2010-04-08
# in loop 29
# home data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 79   408  ATL  THANSON-R  -168   -174     8.0       8      4    8  2010-04-08
# away data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 78   408  CHC  RWELLS-R   148    154     8.0       8      4    8  2010-04-08
# in loop 30
# home data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 91   408  CHW  GFLOYD-R  -143   -138     8.5     8.5      4    8  2010-04-08
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 90   408  CLE  MASTERSON-R   123    118     8.5     8.5      4    8
#
#       game_day
# 90  2010-04-08
# in loop 31
# home data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 85   408   KC  BBANNISTR-R  -105   -119     9.5       9      4    8
#
#       game_day
# 85  2010-04-08
# away data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 84   408  DET  DWILLIS-L  -105   -101     9.5       9      4    8  2010-04-08
# in loop 32
# home data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 73   408  PIT  PMAHOLM-L  -144    124     8.5       8      4    8  2010-04-08
# away data from odds_data Empty DataFrame
# Columns: [Date, Team, Pitcher, Open, Close, OpenOU, CloseOU, month, day, game_day]
# Index: []
# in loop 33
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 77   408  WSN  CSTAMMEN-R   130    133     9.5    10.5      4    8  2010-04-08
# away data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 76   408  PHI  KKENDRICK-R  -150   -153     9.5    10.5      4    8
#
#       game_day
# 76  2010-04-08
# in loop 34
# home data from odds_data     Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 87   408  OAK  BANDERSON-L  -145   -151     8.0       8      4    8
#
#       game_day
# 87  2010-04-08
# away data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 86   408  SEA  DFISTER-R   125    131     8.0       8      4    8  2010-04-08
# in loop 35
# home data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 75   408  CIN  BARROYO-R  -110   -113     8.5       9      4    8  2010-04-08
# away data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 74   408  STL  BPENNY-R  -110   -107     8.5       9      4    8  2010-04-08
# in loop 36
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 119   409   KC  KDAVIES-R   129    131     9.5     9.5      4    9  2010-04-09
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 118   409  BOS  WAKEFIELD-R  -149   -151     9.5     9.5      4    9
#
#        game_day
# 118  2010-04-09
# in loop 37
# home data from odds_data     Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 99   409  CIN  HBAILEY-R  -118   -139     9.5       9      4    9  2010-04-09
# away data from odds_data     Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 98   409  CHC  CSILVA-R  -102    119     9.5       9      4    9  2010-04-09
# in loop 38
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 111   409  DET  RPORCELLO-R  -132   -177     9.0       9      4    9
#
#        game_day
# 111  2010-04-09
# away data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 110   409  CLE  DHUFF-L   112    157     9.0       9      4    9  2010-04-09
# in loop 39
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 121   409  CHW  JDANKS-L  -130   -110     8.5       8      4    9  2010-04-09
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 120   409  MIN  FLIRIANO-L   110   -110     8.5       8      4    9
#
#        game_day
# 120  2010-04-09
# in loop 40
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 123   409  LAA  MPALMER-R  -145   -132     9.0       9      4    9  2010-04-09
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 122   409  OAK  GGONZALEZ-L   125    112     9.0       9      4    9
#
#        game_day
# 122  2010-04-09
# in loop 41
# home data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 95   409  COL  DELAROSA-L  -165   -180     9.5     9.5      4    9  2010-04-09
# away data from odds_data     Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 94   409   SD  CRICHARD-L   145    160     9.5     9.5      4    9  2010-04-09
# in loop 42
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 117   409  TEX  CLEWIS-R  -140   -136     9.0       9      4    9  2010-04-09
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 116   409  SEA  JVARGAS-L   120    116     9.0       9      4    9  2010-04-09
# in loop 43
# home data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 107   409  MIL  DBUSH-R  -110   -105     9.5     9.5      4    9  2010-04-09
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 106   409  STL  KLOHSE-R  -110   -105     9.5     9.5      4    9  2010-04-09
# in loop 44
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 113   409  BAL  BBERGESEN-R  -135   -155     9.0       9      4    9
#
#        game_day
# 113  2010-04-09
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 112   409  TOR  BMORROW-R   115    135     9.0       9      4    9  2010-04-09
# in loop 45
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 101   409  NYM  MPELFREY-R  -160   -132     9.0       9      4    9
#
#        game_day
# 101  2010-04-09
# away data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 100   409  WSN  GMOCK-R   140    112     9.0       9      4    9  2010-04-09
# in loop 46
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 105   409  HOU  BNORRIS-R   132    144     8.5     8.5      4    9  2010-04-09
# away data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 104   409  PHI  JHAPP-L  -152   -164     8.5     8.5      4    9  2010-04-09
# in loop 47
# home data from odds_data      Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 139   410   SF  WELLEMEYER-R   100   -103     8.5       9      4   10
#
#        game_day
# 139  2010-04-10
# away data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 138   410  ATL  DLOWE-R  -120   -117     8.5       9      4   10  2010-04-10
# in loop 48
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 151   410   KC  ZGREINKE-R   100   -110     7.5     7.5      4   10
#
#        game_day
# 151  2010-04-10
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 150   410  BOS  JBECKETT-R  -120   -110     7.5     7.5      4   10
#
#        game_day
# 150  2010-04-10
# in loop 49
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 125   410  CIN  AHARANG-R  -120   -110     8.5     8.5      4   10  2010-04-10
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 124   410  CHC  CZAMBRANO-R   100   -110     8.5     8.5      4   10
#
#        game_day
# 124  2010-04-10
# in loop 50
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 141   410  DET  BONDERMAN-R  -167   -122     9.5     9.5      4   10
#
#        game_day
# 141  2010-04-10
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 140   410  CLE  MTALBOT-R   147    102     9.5     9.5      4   10  2010-04-10
# in loop 51
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 145   410   TB  WDAVIS-R   122    125     9.5       9      4   10  2010-04-10
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 144   410  NYY  CSABATHIA-L  -142   -145     9.5       9      4   10
#
#        game_day
# 144  2010-04-10
# in loop 52
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 153   410  LAA  JERWEAVER-R  -141   -166     8.5       8      4   10
#
#        game_day
# 153  2010-04-10
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 152   410  OAK  BSHEETS-R   121    146     8.5       8      4   10  2010-04-10
# in loop 53
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 137   410  ARI  DHAREN-R  -243   -260     8.5     8.5      4   10  2010-04-10
# away data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 136   410  PIT  ZDUKE-L   203    220     8.5     8.5      4   10  2010-04-10
# in loop 54
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 135   410  COL  JHAMMEL-R  -156   -162     9.5     9.5      4   10  2010-04-10
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 134   410   SD  MLATOS-R   136    142     9.5     9.5      4   10  2010-04-10
# in loop 55
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 149   410  BAL  DHERNANDZ-R  -152   -140     9.0     9.5      4   10
#
#        game_day
# 149  2010-04-10
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 148   410  TOR  DEVELAND-L   132    120     9.0     9.5      4   10
#
#        game_day
# 148  2010-04-10
# in loop 56
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 131   410  HOU  FPAULINO-R   115    135     9.5     9.5      4   10
#
#        game_day
# 131  2010-04-10
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 130   410  PHI  JMOYER-L  -135   -155     9.5     9.5      4   10  2010-04-10
# in loop 57
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 179   411   KC  GMECHE-R   100    147     9.0       9      4   11  2010-04-11
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 178   411  BOS  CBUCHHOLZ-R  -120   -167     9.0       9      4   11
#
#        game_day
# 178  2010-04-11
# in loop 58
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 159   411  CIN  MLEAKE-R  -120   -107     9.0       9      4   11  2010-04-11
# away data from odds_data      Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 158   411  CHC  GORZELANNY-L   100   -113     9.0       9      4   11
#
#        game_day
# 158  2010-04-11
# in loop 59
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 171   411  DET  VERLANDER-R  -200   -220     8.0       8      4   11
#
#        game_day
# 171  2010-04-11
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 170   411  CLE  WESTBROOK-R   170    190     8.0       8      4   11
#
#        game_day
# 170  2010-04-11
# in loop 60
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 177   411  CHW  MBUEHRLE-L  -117   -131     8.5     8.5      4   11
#
#        game_day
# 177  2010-04-11
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 176   411  MIN  NBLACKBUR-R  -103    111     8.5     8.5      4   11
#
#        game_day
# 176  2010-04-11
# in loop 61
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 183   411  LAA  JSAUNDERS-L  -130   -152     9.0       9      4   11
#
#        game_day
# 183  2010-04-11
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 182   411  OAK  DBRADEN-L   110    132     9.0       9      4   11  2010-04-11
# in loop 62
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 167   411  ARI  EJACKSON-R  -200   -200     9.5     9.5      4   11
#
#        game_day
# 167  2010-04-11
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 166   411  PIT  DMCCUTCHE-R   170    170     9.5     9.5      4   11
#
#        game_day
# 166  2010-04-11
# in loop 63
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 181   411  TEX  SFELDMAN-R  -145   -166     9.0       9      4   11
#
#        game_day
# 181  2010-04-11
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 180   411  SEA  ISNELL-R   125    146     9.0       9      4   11  2010-04-11
# in loop 64
# home data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 169   411  MIL  RWOLF-L   110    120     7.5       7      4   11  2010-04-11
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 168   411  STL  CARPENTER-R  -130   -140     7.5       7      4   11
#
#        game_day
# 168  2010-04-11
# in loop 65
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 173   411  BAL  KMILLWOOD-R  -130   -113     9.0     8.5      4   11
#
#        game_day
# 173  2010-04-11
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 172   411  TOR  SMARCUM-R   110   -107     9.0     8.5      4   11  2010-04-11
# in loop 66
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 161   411  HOU  ROSWALT-R   160    190     7.5     7.5      4   11  2010-04-11
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 160   411  PHI  RHALLADAY-R  -180   -220     7.5     7.5      4   11
#
#        game_day
# 160  2010-04-11
# in loop 67
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 165   411   SF  TLINCECUM-R  -201   -180     7.0       7      4   11
#
#        game_day
# 165  2010-04-11
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 164   411  ATL  KKAWAKAMI-R   171    160     7.0       7      4   11
#
#        game_day
# 164  2010-04-11
# in loop 68
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 191   412   SD  KCORREIA-R   125    110     7.5       7      4   12
#
#        game_day
# 191  2010-04-12
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 190   412  ATL  JJURRJENS-R  -145   -130     7.5       7      4   12
#
#        game_day
# 190  2010-04-12
# in loop 69
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 197   412  DET  MSCHERZER-R  -183   -185     8.0       8      4   12
#
#        game_day
# 197  2010-04-12
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 196   412   KC  LHOCHEVAR-R   163    165     8.0       8      4   12
#
#        game_day
# 196  2010-04-12
# in loop 70
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 185   412  CHC  RDEMPSTER-R  -145   -166     9.0       9      4   12
#
#        game_day
# 185  2010-04-12
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 184   412  MIL  DDAVIS-L   125    146     9.0       9      4   12  2010-04-12
# in loop 71
# home data from odds_data      Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 203   412  SEA  RWLND-SMTH-L  -114   -124     8.0     7.5      4   12
#
#        game_day
# 203  2010-04-12
# away data from odds_data      Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 202   412  OAK  DUCHSHERER-R  -106    104     8.0     7.5      4   12
#
#        game_day
# 202  2010-04-12
# in loop 72
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 205   412  BAL  JGUTHRIE-R   135    124     8.5       9      4   12
#
#        game_day
# 205  2010-04-12
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 204   412   TB  MGARZA-R  -155   -144     8.5       9      4   12  2010-04-12
# in loop 73
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 187   412  PHI  CHAMELS-L  -270   -270     9.5       9      4   12  2010-04-12
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 186   412  WSN  JMARQUIS-R   230    230     9.5       9      4   12
#
#        game_day
# 186  2010-04-12
# in loop 74
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 201   412  MIN  CPAVANO-R   123    106     9.0       9      4   12  2010-04-12
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 200   412  BOS  JLESTER-L  -143   -126     9.0       9      4   12  2010-04-12
# in loop 75
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 207   412  TOR  BTALLET-L  -102    107     8.0       8      4   12  2010-04-12
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 206   412  CHW  JPEAVY-R  -118   -127     8.0       8      4   12  2010-04-12
# in loop 76
# home data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 195   412   SF  BZITO-L  -175   -188     8.0     8.5      4   12  2010-04-12
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 194   412  PIT  BBURRES-L   155    168     8.0     8.5      4   12  2010-04-12
# in loop 77
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 219   413  NYY  APETTITTE-L  -155   -200    10.0      10      4   13
#
#        game_day
# 219  2010-04-13
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 218   413  LAA  ESANTANA-R   135    170    10.0      10      4   13
#
#        game_day
# 218  2010-04-13
# in loop 78
# home data from odds_data Empty DataFrame
# Columns: [Date, Team, Pitcher, Open, Close, OpenOU, CloseOU, month, day, game_day]
# Index: []
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 208   413  ARI  IKENNEDY-R   160    149     8.5       8      4   13
#
#        game_day
# 208  2010-04-13
# in loop 79
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 217   413  DET  DWILLIS-L  -130   -116     9.0     9.5      4   13  2010-04-13
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 216   413   KC  BBANNISTR-R   110   -104     9.0     9.5      4   13
#
#        game_day
# 216  2010-04-13
# in loop 80
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 213   413  COL  GSMITH-L  -138   -147    10.0    10.5      4   13  2010-04-13
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 212   413  NYM  JMAINE-R   118    127    10.0    10.5      4   13  2010-04-13
# in loop 81
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 225   413  SEA  DFISTER-R  -103    123     8.0     7.5      4   13  2010-04-13
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 224   413  OAK  BANDERSON-L  -117   -143     8.0     7.5      4   13
#
#        game_day
# 224  2010-04-13
# in loop 82
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 221   413  BAL  BMATUSZ-L  -110    100     9.0     8.5      4   13  2010-04-13
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 220   413   TB  JNIEMANN-R  -110   -120     9.0     8.5      4   13
#
#        game_day
# 220  2010-04-13
# in loop 83
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 223   413  TOR  RROMERO-L  -113   -122     8.0     8.5      4   13  2010-04-13
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 222   413  CHW  GFLOYD-R  -107    102     8.0     8.5      4   13  2010-04-13
# in loop 84
# home data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 215   413   SF  MCAIN-R  -185   -200     7.5     7.5      4   13  2010-04-13
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 214   413  PIT  PMAHOLM-L   165    170     7.5     7.5      4   13  2010-04-13
# in loop 85
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 239   414   SD  CRICHARD-L   128    113     7.0       7      4   14
#
#        game_day
# 239  2010-04-14
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 238   414  ATL  THANSON-R  -148   -133     7.0       7      4   14  2010-04-14
# in loop 86
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 243   414  DET  RPORCELLO-R  -175   -176     9.0     9.5      4   14
#
#        game_day
# 243  2010-04-14
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 242   414   KC  KDAVIES-R   155    156     9.0     9.5      4   14  2010-04-14
# in loop 87
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 227   414  CHC  RWELLS-R  -140   -138    11.0    10.5      4   14  2010-04-14
# away data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 226   414  MIL  DBUSH-R   120    118    11.0    10.5      4   14  2010-04-14
# in loop 88
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 255   414  SEA  JVARGAS-L  -109   -105     8.0     7.5      4   14  2010-04-14
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 254   414  OAK  GGONZALEZ-L  -111   -105     8.0     7.5      4   14
#
#        game_day
# 254  2010-04-14
# in loop 89
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 249   414  BAL  BBERGESEN-R   130    135     9.0       9      4   14
#
#        game_day
# 249  2010-04-14
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 248   414   TB  DPRICE-L  -150   -155     9.0       9      4   14  2010-04-14
# in loop 90
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 253   414  CLE  MASTERSON-R  -113   -114     8.0     8.5      4   14
#
#        game_day
# 253  2010-04-14
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 252   414  TEX  CLEWIS-R  -107   -106     8.0     8.5      4   14  2010-04-14
# in loop 91
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 231   414  PHI  KKENDRICK-R  -230   -178    10.5      10      4   14
#
#        game_day
# 231  2010-04-14
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 230   414  WSN  CSTAMMEN-R   200    158    10.5      10      4   14
#
#        game_day
# 230  2010-04-14
# in loop 92
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 247   414  MIN  KSLOWEY-R   110   -105     8.5       9      4   14  2010-04-14
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 246   414  BOS  JLACKEY-R  -130   -115     8.5       9      4   14  2010-04-14
# in loop 93
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 251   414  TOR  BMORROW-R  -114    101     8.5       8      4   14  2010-04-14
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 250   414  CHW  JDANKS-L  -106   -121     8.5       8      4   14  2010-04-14
# in loop 94
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 235   414  STL  BPENNY-R  -185   -250     8.5     8.5      4   14  2010-04-14
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 234   414  HOU  BMYERS-R   165    210     8.5     8.5      4   14  2010-04-14
# in loop 95
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 277   415  NYY  PHUGHES-R  -180   -160    10.0      10      4   15  2010-04-15
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 276   415  LAA  SKAZMIR-L   160    140    10.0      10      4   15  2010-04-15
# in loop 96
# home data from odds_data Empty DataFrame
# Columns: [Date, Team, Pitcher, Open, Close, OpenOU, CloseOU, month, day, game_day]
# Index: []
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 268   415  ARI  DHAREN-R  -113    113     7.5     7.5      4   15  2010-04-15
# in loop 97
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 265   415   SD  MLATOS-R   110    105     7.5       7      4   15  2010-04-15
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 264   415  ATL  THUDSON-R  -130   -125     7.5       7      4   15  2010-04-15
# in loop 98
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 279   415  OAK  BSHEETS-R  -130   -155     8.5     8.5      4   15  2010-04-15
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 278   415  BAL  DHERNANDZ-R   110    135     8.5     8.5      4   15
#
#        game_day
# 278  2010-04-15
# in loop 99
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 259   415  CHC  CZAMBRANO-R  -158   -163    11.0    11.5      4   15
#
#        game_day
# 259  2010-04-15
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 258   415  MIL  JSUPPAN-R   138    143    11.0    11.5      4   15  2010-04-15
# in loop 100
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 263   415  COL  DELAROSA-L  -190   -195     9.0       9      4   15
#
#        game_day
# 263  2010-04-15
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 262   415  NYM  MPELFREY-R   170    175     9.0       9      4   15
#
#        game_day
# 262  2010-04-15
# in loop 101
# home data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 271   415  CLE  DHUFF-L   105   -108     8.5     8.5      4   15  2010-04-15
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 270   415  TEX  MHARRISON-L  -125   -112     8.5     8.5      4   15
#
#        game_day
# 270  2010-04-15
# in loop 102
# home data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 261   415  PHI  JHAPP-L  -255   -260     9.5     9.5      4   15  2010-04-15
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 260   415  WSN  SOLSEN-L   215    220     9.5     9.5      4   15  2010-04-15
# in loop 103
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 273   415  MIN  FLIRIANO-L  -130   -121     9.0     9.5      4   15
#
#        game_day
# 273  2010-04-15
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 272   415  BOS  WAKEFIELD-R   110    101     9.0     9.5      4   15
#
# ...
# 579   427  NYM    OLPEREZ-L  -160   -108     8.0       9      4   27
# 609   427  NYM  JOSANTANA-L  -140   -139     7.5       7      4   27
#
#        game_day
# 579  2010-04-27
# 609  2010-04-27
# away data from odds_data Empty DataFrame
# Columns: [Date, Team, Pitcher, Open, Close, OpenOU, CloseOU, month, day, game_day]
# Index: []
# in loop 218
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 597   427  DET  VERLANDER-R  -130   -110     8.0     8.5      4   27
#
#        game_day
# 597  2010-04-27
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 596   427  MIN  FLIRIANO-L   110   -110     8.0     8.5      4   27
#
#        game_day
# 596  2010-04-27
# in loop 219
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 599   427  BAL  KMILLWOOD-R   130    163     8.5       9      4   27
#
#        game_day
# 599  2010-04-27
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 598   427  NYY  PHUGHES-R  -150   -183     8.5       9      4   27  2010-04-27
# in loop 220
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 601   427   TB  WDAVIS-R  -155   -176     8.5     8.5      4   27  2010-04-27
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 600   427  OAK  BSHEETS-R   135    156     8.5     8.5      4   27  2010-04-27
# in loop 221
# home data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 587   427  MIL  RWOLF-L  -240   -230     9.0       9      4   27  2010-04-27
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 586   427  PIT  JKARSTENS-R   200    200     9.0       9      4   27
#
#        game_day
# 586  2010-04-27
# in loop 222
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 605   427   KC  ZGREINKE-R  -165   -200     7.5     7.5      4   27
#
#        game_day
# 605  2010-04-27
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 604   427  SEA  ISNELL-R   145    170     7.5     7.5      4   27  2010-04-27
# in loop 223
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 595   427  TOR  SMARCUM-R  -112   -105     8.5     8.5      4   27  2010-04-27
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 594   427  BOS  CBUCHHOLZ-R  -108   -105     8.5     8.5      4   27
#
#        game_day
# 594  2010-04-27
# in loop 224
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 585   427  HOU  BNORRIS-R  -115   -132     9.0       9      4   27  2010-04-27
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 584   427  CIN  AHARANG-R  -105    112     9.0       9      4   27  2010-04-27
# in loop 225
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 589   427  STL  CARPENTER-R  -170   -176     7.5     7.5      4   27
#
#        game_day
# 589  2010-04-27
# away data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 588   427  ATL  DLOWE-R   150    156     7.5     7.5      4   27  2010-04-27
# in loop 226
# home data from odds_data      Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 593   427   SF  WELLEMEYER-R  -107    123     9.5     9.5      4   27
#
#        game_day
# 593  2010-04-27
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 592   427  PHI  JMOYER-L  -113   -143     9.5     9.5      4   27  2010-04-27
# in loop 227
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 619   428  COL  GSMITH-L  -155   -148    10.5      11      4   28  2010-04-28
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 618   428  ARI  KBENSON-R   135    128    10.5      11      4   28  2010-04-28
# in loop 228
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 639   428  TEX  RHARDEN-R  -118   -120     9.0       9      4   28  2010-04-28
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 638   428  CHW  JPEAVY-R  -102    100     9.0       9      4   28  2010-04-28
# in loop 229
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 631   428  LAA  ESANTANA-R  -152   -169     9.0       9      4   28
#
#        game_day
# 631  2010-04-28
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 630   428  CLE  WESTBROOK-R   132    149     9.0       9      4   28
#
#        game_day
# 630  2010-04-28
# in loop 230
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 615   428  NYM  JMAINE-R  -114   -114     9.5       9      4   28  2010-04-28
# away data from odds_data Empty DataFrame
# Columns: [Date, Team, Pitcher, Open, Close, OpenOU, CloseOU, month, day, game_day]
# Index: []
# in loop 231
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 629   428  DET  MSCHERZER-R  -106   -112     8.5     8.5      4   28
#
#        game_day
# 629  2010-04-28
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 628   428  MIN  SBAKER-R  -114   -108     8.5     8.5      4   28  2010-04-28
# in loop 232
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 633   428  BAL  JGUTHRIE-R   170    210     8.5     8.5      4   28
#
#        game_day
# 633  2010-04-28
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 632   428  NYY  CSABATHIA-L  -200   -250     8.5     8.5      4   28
#
#        game_day
# 632  2010-04-28
# in loop 233
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 637   428   TB  JSHIELDS-R  -158   -155     8.5     8.5      4   28
#
#        game_day
# 637  2010-04-28
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 636   428  OAK  DBRADEN-L   138    135     8.5     8.5      4   28  2010-04-28
# in loop 234
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 613   428  MIL  CNARVESON-L  -136   -151     9.5     9.5      4   28
#
#        game_day
# 613  2010-04-28
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 612   428  PIT  PMAHOLM-L   116    131     9.5     9.5      4   28  2010-04-28
# in loop 235
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 627   428   KC  GMECHE-R  -110   -103     9.5     9.5      4   28  2010-04-28
# away data from odds_data      Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 626   428  SEA  RWLND-SMTH-L  -110   -117     9.5     9.5      4   28
#
#        game_day
# 626  2010-04-28
# in loop 236
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 617   428  CHC  RDEMPSTER-R  -210   -200     8.5       8      4   28
#
#        game_day
# 617  2010-04-28
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 616   428  WSN  LATILANO-R   180    170     8.5       8      4   28
#
#        game_day
# 616  2010-04-28
# in loop 237
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 621   428   SF  TLINCECUM-R  -154   -147     7.0       7      4   28
#
#        game_day
# 621  2010-04-28
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 620   428  PHI  CHAMELS-L   134    127     7.0       7      4   28  2010-04-28
# in loop 238
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 635   428  TOR  BCECIL-L   137    126     9.0     8.5      4   28  2010-04-28
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 634   428  BOS  JLESTER-L  -157   -146     9.0     8.5      4   28  2010-04-28
# in loop 239
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 623   428  HOU  FPAULINO-R  -118   -105     9.0       9      4   28
#
#        game_day
# 623  2010-04-28
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 622   428  CIN  MLEAKE-R  -102   -105     9.0       9      4   28  2010-04-28
# in loop 240
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 643   429  CHC  TLILLY-L  -154   -155    12.5      13      4   29  2010-04-29
# away data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 642   429  ARI  IKENNEDY-R   134    135    12.5      13      4   29
#
#        game_day
# 642  2010-04-29
# in loop 241
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 653   429  TEX  SFELDMAN-R  -130   -121     9.5       9      4   29
#
#        game_day
# 653  2010-04-29
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 652   429  CHW  GFLOYD-R   110    101     9.5       9      4   29  2010-04-29
# in loop 242
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 659   429   TB  MGARZA-R  -240   -240     8.5     8.5      4   29  2010-04-29
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 658   429   KC  LHOCHEVAR-R   200    200     8.5     8.5      4   29
#
#        game_day
# 658  2010-04-29
# in loop 243
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 647   429   SD  WLEBLANC-L  -132   -137     7.0     7.5      4   29
#
#        game_day
# 647  2010-04-29
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 646   429  MIL  DDAVIS-L   112    117     7.0     7.5      4   29  2010-04-29
# in loop 244
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 651   429  DET  DWILLIS-L   125    108     9.5     9.5      4   29  2010-04-29
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 650   429  MIN  CPAVANO-R  -145   -128     9.5     9.5      4   29  2010-04-29
# in loop 245
# home data from odds_data Empty DataFrame
# Columns: [Date, Team, Pitcher, Open, Close, OpenOU, CloseOU, month, day, game_day]
# Index: []
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 648   429  PIT  BBURRES-L   189    250     8.0     8.5      4   29  2010-04-29
# in loop 246
# home data from odds_data      Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 641   429  STL  WAINWRIGHT-R  -200   -161     7.0       7      4   29
#
#        game_day
# 641  2010-04-29
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 640   429  ATL  JJURRJENS-R   170    141     7.0       7      4   29
#
#        game_day
# 640  2010-04-29
# in loop 247
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 657   429  TOR  RROMERO-L  -135   -158     7.5     7.5      4   29  2010-04-29
# away data from odds_data      Date Team       Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 656   429  OAK  DUCHSHERER-R   115    138     7.5     7.5      4   29
#
#        game_day
# 656  2010-04-29
# in loop 248
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 645   429  HOU  ROSWALT-R  -170   -165     7.5     7.5      4   29  2010-04-29
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 644   429  CIN  BARROYO-R   150    145     7.5     7.5      4   29  2010-04-29
# in loop 249
# home data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 683   430  BAL  DHERNANDZ-R   132    135     9.0       9      4   30
#
#        game_day
# 683  2010-04-30
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 682   430  BOS  JLACKEY-R  -152   -155     9.0       9      4   30  2010-04-30
# in loop 250
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 667   430  ATL  THANSON-R  -200   -210     8.0       8      4   30  2010-04-30
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 666   430  HOU  BMYERS-R   170    180     8.0       8      4   30  2010-04-30
# in loop 251
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 687   430   TB  JNIEMANN-R  -205   -260     9.0     9.5      4   30
#
#        game_day
# 687  2010-04-30
# away data from odds_data      Date Team      Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 686   430   KC  BBANNISTR-R   175    220     9.0     9.5      4   30
#
#        game_day
# 686  2010-04-30
# in loop 252
# home data from odds_data      Date Team     Pitcher  Open  Close  OpenOU CloseOU  month  day  \
# 671   430   SD  CRICHARD-L  -116   -134     7.5     7.5      4   30
#
#        game_day
# 671  2010-04-30
# away data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 670   430  MIL  DBUSH-R  -104    114     7.5     7.5      4   30  2010-04-30
# in loop 253
# home data from odds_data Empty DataFrame
# Columns: [Date, Team, Pitcher, Open, Close, OpenOU, CloseOU, month, day, game_day]
# Index: []
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 672   430  PIT  CMORTON-R   215    220     8.5     8.5      4   30  2010-04-30
# in loop 254
# home data from odds_data      Date Team Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 689   430  SEA  CLEE-L  -148   -133     7.0       7      4   30  2010-04-30
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 688   430  TEX  CLEWIS-R   128    113     7.0       7      4   30  2010-04-30
# in loop 255
# home data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 681   430  TOR  BMORROW-R  -133   -125     9.0       9      4   30  2010-04-30
# away data from odds_data      Date Team    Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 680   430  OAK  TCAHILL-R   113    105     9.0       9      4   30  2010-04-30
# in loop 256
# home data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 669   430  STL  BPENNY-R  -190   -200     7.5       8      4   30  2010-04-30
# away data from odds_data      Date Team   Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 668   430  CIN  JCUETO-R   170    170     7.5       8      4   30  2010-04-30
# in loop 257
# home data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 675   430   SF  BZITO-L  -124   -133     7.5     7.5      4   30  2010-04-30
# away data from odds_data      Date Team  Pitcher  Open  Close  OpenOU CloseOU  month  day    game_day
# 674   430  COL  ACOOK-R   104    113     7.5     7.5      4   30  2010-04-30

# %%
df = open("cleaned_data.pickle","rb")
df=pickle.load(df)
#print(df[df['home_money_close'] != 0]['home_money_close'])
'''
for column in df.columns:
    if df[column].nunique() == 1:
        print(f"Column '{column}' has all the same values.")
    else:
        print(f"Column '{column}' does not have all the same values.")
'''

columns_to_check = ['home_bat_est_ba_sa', 'home_bat_est_woba_sa', 'home_bat_sum_woba', 'away_bat_est_ba_sa',
                   'away_bat_est_woba_sa', 'away_bat_sum_woba', 'homepen_est_ba_sa', 'homepen_est_woba_sa',
                   'homepen_sum_woba', 'awaypen_est_ba_sa', 'awaypen_est_woba_sa', 'awaypen_sum_woba']
exists = df.columns.isin(columns_to_check).any()
if exists:
    print("At least one of the columns exists.")
else:
    print("None of the columns exist.")

'''
print(df['home_bat_est_ba_sa'])
print(df['home_bat_est_woba_sa'])
print(df['home_bat_sum_woba'])
print(df['away_bat_est_ba_sa'])
print(df['away_bat_est_woba_sa'])
print(df['away_bat_sum_woba'])
print(df['homepen_est_ba_sa'])
print(df['homepen_est_woba_sa'])
print(df['homepen_sum_woba'])
print(df['awaypen_est_ba_sa'])
print(df['awaypen_est_woba_sa'])
print(df['awaypen_sum_woba'])
'''
df.sample(30)

row = df.iloc[200]

# Iterate through columns and values in the selected row
for column, value in row.items():
    print(f"{column}: {value}")
# Out:
# At least one of the columns exists.
# home_win: 1
# home_score: 8.0
# away_score: 4.0
# home_pct: 0
# away_pct: 0
# home_streak: 0
# away_streak: 0
# home_starter_launch: 0.0
# home_starter_est_ba_sa: 0.0
# home_starter_est_woba_sa: 0.0
# home_starter_sum_woba: 0.0
# away_starter_launch: 0.0
# away_starter_est_ba_sa: 0.0
# away_starter_est_woba_sa: 0.0
# away_starter_sum_woba: 0.0
# hsG: 4
# hsGS: 4
# hsW: 3.0
# hsL: 0.0
# hsSV: 0.0
# hsIP: 23.2
# hsH: 20
# hsR: 10
# hsER: 10
# hsBB: 12
# hsSO: 28
# hsHR: 2
# hsHBP: 2
# hsERA: 3.8
# hsAB: 88
# hs2B: 6
# hs3B: 0
# hsIBB: 0
# hsGDP: 2
# hsSF: 0
# hsSB: 0
# hsCS: 1
# hsPO: 0
# hsBF: 102
# hsPit: 431
# hsStr: 0.63
# hsStL: 0.19
# hsStS: 0.12
# hsGB/FB: 0.38
# hsLD: 0.2
# hsPU: 0.1
# hsWHIP: 1.352
# hsBAbip: 0.31
# hsSO9: 10.6
# hsSO/W: 2.33
# hsmlbID: 407890
# asG: 4
# asGS: 4
# asW: 1.0
# asL: 2.0
# asSV: 0.0
# asIP: 19.1
# asH: 33
# asR: 17
# asER: 17
# asBB: 6
# asSO: 13
# asHR: 2
# asHBP: 2
# asERA: 7.91
# asAB: 84
# as2B: 6
# as3B: 0
# asIBB: 0
# asGDP: 5
# asSF: 0
# asSB: 1
# asCS: 2
# asPO: 0
# asBF: 92
# asPit: 351
# asStr: 0.61
# asStL: 0.2
# asStS: 0.07
# asGB/FB: 0.58
# asLD: 0.1
# asPU: 0.01
# asWHIP: 2.017
# asBAbip: 0.449
# asSO9: 6.1
# asSO/W: 2.17
# asmlbID: 519144
# home_bat_ab: 588
# home_bat_runs: 79
# home_bat_hits: 144
# home_bat_doub: 27
# home_bat_trip: 4
# home_bat_hr: 13
# home_bat_rbi: 73
# home_bat_bb: 75
# home_bat_avg: 0.245
# home_bat_obp: 0.372
# home_bat_slg: 0.371
# home_bat_est_ba_sa: 0
# home_bat_est_woba_sa: 0
# home_bat_sum_woba: 0.0
# away_bat_ab: 658
# away_bat_runs: 88
# away_bat_hits: 182
# away_bat_doub: 50
# away_bat_trip: 3
# away_bat_hr: 11
# away_bat_rbi: 78
# away_bat_bb: 99
# away_bat_avg: 0.277
# away_bat_obp: 0.427
# away_bat_slg: 0.412
# away_bat_est_ba_sa: 0
# away_bat_est_woba_sa: 0
# away_bat_sum_woba: 0.0
# homepen_innings: 81.0
# homepen_hits: 7.888888888888889
# homepen_bb: 4.444444444444445
# homepen_k: 7.222222222222222
# homepen_at_bats: 32.888888888888886
# homepen_doub: 1.5555555555555556
# homepen_trip: 0.1111111111111111
# homepen_hr: 0.8888888888888888
# homepen_era: 3.0
# homepen_ba: 0.2398648648648649
# homepen_slg: 0.375
# homepen_obp: 0.33
# homepen_est_ba_sa: 0
# homepen_est_woba_sa: 0
# homepen_sum_woba: 0.0
# awaypen_innings: 57.33333333333333
# awaypen_hits: 7.22093023255814
# awaypen_bb: 4.552325581395349
# awaypen_k: 6.750000000000001
# awaypen_at_bats: 32.18023255813954
# awaypen_doub: 0.9418604651162792
# awaypen_trip: 0.1569767441860465
# awaypen_hr: 0.627906976744186
# awaypen_era: 1.5697674418604652
# awaypen_ba: 0.22439024390243903
# awaypen_slg: 0.322
# awaypen_obp: 0.321
# awaypen_est_ba_sa: 0
# awaypen_est_woba_sa: 0
# awaypen_sum_woba: 0.0
# home_money_open: -126
# home_money_change: -24
# away_money_open: 106
# away_money_change: 24
# home_prob_open: 0.5345580360820495
# home_prob_close: 0.5798319327731092
# home_prob_change: 0.045273896691059634
# ou_open: 9.0
# ou_close: 9.5
# h_ARI: False
# h_ATL: False
# h_BAL: False
# h_BOS: False
# h_CHC: False
# h_CHW: False
# h_CIN: False
# h_CLE: False
# h_COL: False
# h_DET: False
# h_HOU: False
# h_KC: False
# h_LAA: False
# h_LAD: False
# h_MIL: False
# h_MIN: False
# h_NYM: False
# h_NYY: False
# h_OAK: False
# h_PHI: False
# h_PIT: False
# h_SD: False
# h_SEA: False
# h_SF: False
# h_STL: False
# h_TB: False
# h_TEX: True
# h_TOR: False
# h_WSN: False
# a_ARI: False
# a_ATL: False
# a_BAL: False
# a_BOS: False
# a_CHC: False
# a_CHW: False
# a_CIN: False
# a_CLE: False
# a_COL: False
# a_DET: True
# a_HOU: False
# a_KC: False
# a_LAA: False
# a_LAD: False
# a_MIL: False
# a_MIN: False
# a_NYM: False
# a_NYY: False
# a_OAK: False
# a_PHI: False
# a_PIT: False
# a_SD: False
# a_SEA: False
# a_SF: False
# a_STL: False
# a_TB: False
# a_TEX: False
# a_TOR: False
# a_WSN: False
# home_money_close: -150
# away_money_close: 130

# %%
df.describe()
len(df)
# Out:
# 258

# %%
df.dtypes
# Out:
# home_win              int64
# home_score          float64
# away_score          float64
# home_pct              int64
# away_pct              int64
#                      ...
# a_TEX                  bool
# a_TOR                  bool
# a_WSN                  bool
# home_money_close      int64
# away_money_close      int64
# Length: 214, dtype: object
